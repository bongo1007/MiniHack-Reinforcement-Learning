# %% [markdown]
# # Actor Critic Agent for MiniHack-Quest-Hard-v0 using Random Actions Only

# %% [markdown]
# # Setup

# %% [markdown]
# Just doing installs of needed libraries so notebook can run on Colab.

# %%
 # !sudo apt-get install -y build-essential autoconf libtool pkg-config \
     python3-dev python3-pip python3-numpy git libncurses5-dev \
     libzmq3-dev flex bison
# !git clone https://github.com/google/flatbuffers.git
# !cd flatbuffers && cmake -G "Unix Makefiles" && make && sudo make install
# !pip install cmake==3.15.3
# !pip install nle
# !pip install pyvirtualdisplay
# !pip install minihack
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# autoconf is already the newest version (2.69-11).
# bison is already the newest version (2:3.0.4.dfsg-1build1).
# build-essential is already the newest version (12.4ubuntu1).
# flex is already the newest version (2.6.4-6).
# libtool is already the newest version (2.4.6-2).
# pkg-config is already the newest version (0.29.1-0ubuntu2).
# python3-numpy is already the newest version (1:1.13.3-2ubuntu1).
# git is already the newest version (1:2.17.1-1ubuntu0.9).
# libncurses5-dev is already the newest version (6.1-1ubuntu1.18.04).
# python3-dev is already the newest version (3.6.7-1~18.04).
# libzmq3-dev is already the newest version (4.2.5-1ubuntu0.2).
# python3-pip is already the newest version (9.0.1-2.3~ubuntu1.18.04.5).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# fatal: destination path 'flatbuffers' already exists and is not an empty directory.
# CMake Warning:
#   No source or binary directory provided.  Both will be assumed to be the
#   same as the current working directory, but note that this warning will
#   become a fatal error in future CMake releases.
#
#
# -- CMAKE_CXX_FLAGS:  -std=c++0x -Wall -pedantic -Werror -Wextra -Werror=shadow -faligned-new -Werror=implicit-fallthrough=2 -Wunused-result -Werror=unused-result -Wunused-parameter -Werror=unused-parameter -fsigned-char
# -- `tests/monster_test.fbs`: add generation of C++ code with '--no-includes;--gen-compare'
# -- `tests/monster_test.fbs`: add generation of binary (.bfbs) schema
# -- `tests/namespace_test/namespace_test1.fbs`: add generation of C++ code with '--no-includes;--gen-compare;--gen-name-strings'
# -- `tests/namespace_test/namespace_test2.fbs`: add generation of C++ code with '--no-includes;--gen-compare;--gen-name-strings'
# -- `tests/union_vector/union_vector.fbs`: add generation of C++ code with '--no-includes;--gen-compare;--gen-name-strings'
# -- `tests/optional_scalars.fbs`: add generation of C++ code with '--no-includes;--gen-compare'
# -- `tests/native_type_test.fbs`: add generation of C++ code with ''
# -- `tests/arrays_test.fbs`: add generation of C++ code with '--scoped-enums;--gen-compare'
# -- `tests/arrays_test.fbs`: add generation of binary (.bfbs) schema
# -- `tests/monster_test.fbs`: add generation of C++ embedded binary schema code with '--no-includes;--gen-compare'
# -- `tests/monster_extra.fbs`: add generation of C++ code with '--no-includes;--gen-compare'
# -- `samples/monster.fbs`: add generation of C++ code with '--no-includes;--gen-compare'
# -- `samples/monster.fbs`: add generation of binary (.bfbs) schema
# -- Proceeding with version: 1.12.0.501
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /content/flatbuffers
# [ 34%] Built target flatc
# [ 36%] Built target flathash
# [ 42%] Built target flatbuffers
# [ 43%] All generated files were updated.
# [ 57%] Built target generated_code
# [ 65%] Built target flatsamplebfbs
# [ 69%] Built target flatsamplebinary
# [ 92%] Built target flattests
# [100%] Built target flatsampletext
# [ 34%] Built target flatc
# [ 36%] Built target flathash
# [ 42%] Built target flatbuffers
# [ 43%] All generated files were updated.
# [ 57%] Built target generated_code
# [ 65%] Built target flatsamplebfbs
# [ 69%] Built target flatsamplebinary
# [ 92%] Built target flattests
# [100%] Built target flatsampletext
# Install the project...
# -- Install configuration: ""
# -- Up-to-date: /usr/local/include/flatbuffers
# -- Up-to-date: /usr/local/include/flatbuffers/code_generators.h
# -- Up-to-date: /usr/local/include/flatbuffers/idl.h
# -- Up-to-date: /usr/local/include/flatbuffers/flatc.h
# -- Up-to-date: /usr/local/include/flatbuffers/reflection_generated.h
# -- Up-to-date: /usr/local/include/flatbuffers/flatbuffers.h
# -- Up-to-date: /usr/local/include/flatbuffers/hash.h
# -- Up-to-date: /usr/local/include/flatbuffers/stl_emulation.h
# -- Up-to-date: /usr/local/include/flatbuffers/flexbuffers.h
# -- Up-to-date: /usr/local/include/flatbuffers/registry.h
# -- Up-to-date: /usr/local/include/flatbuffers/grpc.h
# -- Up-to-date: /usr/local/include/flatbuffers/reflection.h
# -- Up-to-date: /usr/local/include/flatbuffers/util.h
# -- Up-to-date: /usr/local/include/flatbuffers/pch
# -- Up-to-date: /usr/local/include/flatbuffers/pch/flatc_pch.h
# -- Up-to-date: /usr/local/include/flatbuffers/pch/pch.h
# -- Up-to-date: /usr/local/include/flatbuffers/base.h
# -- Up-to-date: /usr/local/include/flatbuffers/minireflect.h
# -- Up-to-date: /usr/local/lib/cmake/flatbuffers/FlatbuffersConfig.cmake
# -- Up-to-date: /usr/local/lib/cmake/flatbuffers/FlatbuffersConfigVersion.cmake
# -- Up-to-date: /usr/local/lib/libflatbuffers.a
# -- Up-to-date: /usr/local/lib/cmake/flatbuffers/FlatbuffersTargets.cmake
# -- Installing: /usr/local/lib/cmake/flatbuffers/FlatbuffersTargets-noconfig.cmake
# -- Up-to-date: /usr/local/bin/flatc
# -- Up-to-date: /usr/local/lib/cmake/flatbuffers/FlatcTargets.cmake
# -- Installing: /usr/local/lib/cmake/flatbuffers/FlatcTargets-noconfig.cmake
# -- Up-to-date: /usr/local/lib/pkgconfig/flatbuffers.pc
# Requirement already satisfied: cmake==3.15.3 in /usr/local/lib/python3.7/dist-packages (3.15.3)
# Requirement already satisfied: nle in /usr/local/lib/python3.7/dist-packages (0.7.3)
# Requirement already satisfied: gym>=0.15 in /usr/local/lib/python3.7/dist-packages (from nle) (0.17.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from nle) (1.19.5)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from nle) (2.8.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.15->nle) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym>=0.15->nle) (1.4.1)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym>=0.15->nle) (1.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym>=0.15->nle) (0.16.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.7/dist-packages (2.2)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.7/dist-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: minihack in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: gym<0.20 in /usr/local/lib/python3.7/dist-packages (from minihack) (0.17.3)
# Requirement already satisfied: nle>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from minihack) (0.7.3)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.7/dist-packages (from minihack) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym<0.20->minihack) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym<0.20->minihack) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym<0.20->minihack) (1.3.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from nle>=0.7.3->minihack) (2.8.1)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<0.20->minihack) (0.16.0)

# %% [markdown]
# # Imports

# %% [markdown]
# Just doing imports of needed libraries so notebook can run on Colab.

# %%
import os
import matplotlib as mp
import matplotlib.pyplot as plt
import numpy as np
import gym
import nle
import random
from gym import spaces
from nle import nethack
import minihack
from minihack import RewardManager
from collections import deque
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
from torch.distributions import Categorical

# %% [markdown]
# Ensures pytorch uses the correct device and that we have the correct directory to be used.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
cwd = os.getcwd()

# %% [markdown]
# Mount google drive on Colab so files can be accessed and made.

# %%
Colab = True

if Colab:
    from google.colab import files, drive
    drive.mount('/content/drive')
    dir = '/content/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/'
    os.makedirs(dir, exist_ok=True)
else:
    dir = './'

path = lambda fname: os.path.join(dir, fname)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Actor Critic Model Class
#
# Here we have define our Actor Critic Model Network and its necessary functions.

# %%
class ACNetwork(nn.Module):
    def __init__(self,observation_shape,num_actions):
        super(ACNetwork, self).__init__()
        #use colors_crop as observation space
        self.glyph_shape = observation_shape["colors_crop"].shape
        #size of blstats which is included in observation space
        self.blstats_size = 12 
        #num actions available
        self.num_actions = num_actions
        #get height and width of colors_crop
        self.H = self.glyph_shape[0]
        self.W = self.glyph_shape[1]

        #set some constants to be used in the network
        self.k_dim = 32
        self.h_dim = 128
        self.crop_dim = 3
        #get crop dimensions
        self.crop = Crop(self.H, self.W, self.crop_dim, self.crop_dim)
        #make lookup table that stores embeddings of a fixed dictionary and size
        self.embed = nn.Embedding(16, self.k_dim)

        #set more constants to be used in the network
        K = 32  # number of input filters
        F = 3  # filter dimensions
        S = 1  # stride
        P = 1  # padding
        M = 16  # number of intermediate filters
        Y = 8  # number of output filters
        L = 2  # number of convnet layers

        #determine input size for network
        in_channels = [K] + [M] * (L - 1)
        #determine output size for network
        out_channels = [M] * (L - 1) + [Y]

        def interleave(xs, ys):
            return [val for pair in zip(xs, ys) for val in pair]

        # CNN normal model
        conv_extract = [nn.Conv2d(in_channels=in_channels[i],out_channels=out_channels[i],kernel_size=(F, F),stride=S,padding=P,)for i in range(L)]
        self.extract_representation = nn.Sequential(*interleave(conv_extract, [nn.ELU()] * len(conv_extract)))

        # CNN crop model
        conv_extract_crop = [nn.Conv2d(in_channels=in_channels[i],out_channels=out_channels[i],kernel_size=(F, F),stride=S,padding=P,)for i in range(L)]
        self.extract_crop_representation = nn.Sequential(*interleave(conv_extract_crop, [nn.ELU()] * len(conv_extract_crop)))

        out_dim = self.k_dim
        # CNN over full glyph map
        out_dim += self.H * self.W * Y
        # CNN over full crop model
        out_dim += self.crop_dim ** 2 * Y

        # define policy,state_value among other things 
        self.embed_blstats = nn.Sequential(nn.Linear(self.blstats_size, self.k_dim),nn.ReLU(),nn.Linear(self.k_dim, self.k_dim),nn.ReLU(),)
        self.fc = nn.Sequential(nn.Linear(out_dim, self.h_dim),nn.ReLU(),nn.Linear(self.h_dim, self.h_dim),nn.ReLU(),)
        self.policy = nn.Linear(self.h_dim, self.num_actions)
        self.state_value = nn.Linear(self.h_dim, 1)

    # make backward pass of embedding faster
    def _select(self, embed, x):
        out = embed.weight.index_select(0, x.reshape(-1))
        return out.reshape(x.shape + (-1,))

    #propagate state through network
    def forward(self, state):
        #get colors crop and blstats
        colors_crop = state["colors_crop"]
        blstats = state["blstats"]
        #get shape of colors
        T, B, *_ = colors_crop.shape
        #flatten it
        colors_crop = torch.flatten(colors_crop, 0, 1)  # Merge time and batch.

        #reshape blstats and make float
        blstats = blstats.view(T * B, -1).float()

        #make long
        colors_crop = colors_crop.long()
        #get x,y coordinates
        coordinates = blstats[:, :2]
        #reshape again
        blstats = blstats.view(T * B, -1).float()
    
        #embed blstats
        blstats_emb = self.embed_blstats(blstats)
        #check if shape is correct
        assert blstats_emb.shape[0] == T * B
        #get representations
        reps = [blstats_emb] 

        #get crop with required coords from blstats
        crop = self.crop(colors_crop, coordinates)
        #embed,make faster with select and transpose
        crop_emb = self._select(self.embed, crop).transpose(1, 3) 
        #get representation and reshape
        crop_rep = self.extract_crop_representation(crop_emb).view(T * B, -1)
        #check shape is correct
        assert crop_rep.shape[0] == T * B
        #append representation
        reps.append(crop_rep)

        #again embed, make faster and transpose
        colors_crop_emb = self._select(self.embed, colors_crop).transpose(1, 3) 
        #get representation and reshape
        colors_crop_rep = self.extract_representation(colors_crop_emb).view(T * B, -1)
        #check shape is correct
        assert colors_crop_rep.shape[0] == T * B
        #append representation
        reps.append(colors_crop_rep)

        #concatenate representations and pass
        st = self.fc(torch.cat(reps, dim=1)) 
        #get policy_logits and state_value
        policy_logits = self.policy(st)
        state_value = self.state_value(st)
        #get probabilities and distributions
        prob = F.softmax(policy_logits,dim=-1)
        dist = Categorical(prob)
        return dist, state_value

# %% [markdown]
# Function to compute returns of model during training with gamma = 0.99.

# %%
def compute_returns(next_value, rewards, masks, gamma=0.99):
    R = next_value
    returns = []
    for step in reversed(range(len(rewards))):
        R = rewards[step] + gamma * R * masks[step]
        returns.insert(0, R)
    return returns

# %% [markdown]
# # Crop Class
# This class assists us in cropping our observations to our desired dimensions.

# %%
class Crop(nn.Module):
    #define constructor
    def __init__(self, height, width, height_target, width_target):
        super(Crop, self).__init__()
        self.width = width
        self.height = height
        self.width_target = width_target
        self.height_target = height_target

        #calculate grid width and height and store
        width_grid = self._step_to_range(2 / (self.width - 1), self.width_target)[None, :].expand(self.height_target, -1)
        height_grid = self._step_to_range(2 / (self.height - 1), height_target)[:, None].expand(-1, self.width_target)
        self.register_buffer("width_grid", width_grid.clone())
        self.register_buffer("height_grid", height_grid.clone())

    #function will assist us with finding width and grid heights above
    def _step_to_range(self,delta, num_steps):
        return delta * torch.arange(-num_steps // 2, num_steps // 2)

    #actually extract grid centrred around agent and return
    def forward(self, inputs, coordinates):
        #ensure shapes are valid
        assert inputs.shape[1] == self.height, f'{ inputs.shape[1],self.height}'
        assert inputs.shape[2] == self.width

        #get observations as floats
        inputs = inputs[:, None, :, :].float()

        #get coords of agent
        x = coordinates[:, 0]
        y = coordinates[:, 1]

        #find shift from centred agent
        x_shift = 2 / (self.width - 1) * (x.float() - self.width // 2)
        y_shift = 2 / (self.height - 1) * (y.float() - self.height // 2)

        #extract grid and return
        grid = torch.stack([self.width_grid[None, :, :] + x_shift[:, None, None],self.height_grid[None, :, :] + y_shift[:, None, None],],dim=3,)
        return (torch.round(F.grid_sample(inputs, grid, align_corners=True)).squeeze(1).long())

# %% [markdown]
# # Save Model and To Device Function

# %% [markdown]
# This function is used to create checkpoints during training.

# %%
def save_checkpoint(fname,policy_model,optimizer,current_step_number,scores,train_loss,download=False):
    #define what to save
    checkpoint = {'current_step_number': current_step_number,'scores': scores,'train_loss': train_loss,'model_state_dict': policy_model.state_dict(),'optimizer_state_dict': optimizer.state_dict()}
    #save
    torch.save(checkpoint, path(fname))
    if download and Colab: files.download(path)

# %% [markdown]
# This function loads our data to the correct pytorch device for usage.

# %%
def dict_to_device(dic):
    for key, value in dic.items():
        dic[key] = dic[key].to(device)
    return dic

# %% [markdown]
# # Extra functions used for visited matrices and formatting state observations.

# %% [markdown]
# This function here gets info of adjacent cells to agent and gets best cell info.

# %%
def get_info_about_adjacent_cells(visited_matrix, curr_pos):
    min_adj_val = 1000
    min_adj_ind = -1
    min_adj_pos = [-1, -1]
    adj_cell_info = np.zeros(12)

    count = 0
    for i in range(2):
        for j in range(2):
            curr_adj_pos = [curr_pos[0], curr_pos[1]]
            plus_or_minus = 1
            if j == 0:
                plus_or_minus = -1

            curr_adj_pos[i] = curr_adj_pos[i]+plus_or_minus

            #Check if the pos is out of bounds
            if curr_adj_pos[0] < 0 or curr_adj_pos[1] < 0 or curr_adj_pos[0] >= 21 or curr_adj_pos[1] >= 79:
                continue

            curr_adj_val = min(1000, visited_matrix[curr_adj_pos[0]][curr_adj_pos[1]])

            if curr_adj_val == 1000: # Then it is unvisited
                adj_cell_info[count] = 1.0
            elif curr_adj_val < min_adj_val: # Then it is visited
                min_adj_val = curr_adj_val
                min_adj_ind = count
                min_adj_pos = curr_adj_pos

            adj_cell_info[count+8] = curr_adj_val/1000.0
            count+=1

    if min_adj_ind != -1:
        adj_cell_info[min_adj_ind+4] = 1.0

    return adj_cell_info, min_adj_pos

# %% [markdown]
# This function updates the visited matrix every time a move is made.

# %%
def update_visited_matrix(vis_mat, curr_pos):
    vis_mat = vis_mat + 1.0
    #set where agent is to 0
    vis_mat[curr_pos[0]][curr_pos[1]] = 0.0 
    return vis_mat

# %% [markdown]
# This function formats the observations(colors_crop and visited matrix(using blstats)) into a format to be used.

# %%
def format_observations(observation,visited_count_map, keys=("colors_crop", "blstats")):
    observations = {}
    entry = observation["colors_crop"]
    entry = torch.from_numpy(entry)
    entry = entry.view((1, 1) + entry.shape)  
    observations["colors_crop"] = entry

    adj_cell_info, recent_vis_cell = get_info_about_adjacent_cells(visited_count_map, (observation['blstats'][1], observation['blstats'][0]))
    adj_cell_info = torch.from_numpy(adj_cell_info)
    observations["blstats"] = adj_cell_info

    return observations, recent_vis_cell

# %% [markdown]
# # Train Function
# This function trains our model defined above using a TD Actor Critic approach(5 step td update). It uses and Adam Optimizer with LR = 0.001. It returns scores over episodes.

# %%
def train_ac(env, number_episodes, gamma, verbose=True):
    #define 5 step td update
    num_step_td_update = 5

    #define array to store scores
    scores = [0]

    #define array to count how many times each subtask is done
    countSubtaskDone = [0,0,0,0]

    #initialise step number
    current_step_number = 0


    #array to store which episodes completed the maze
    solved_count = []

    #reset environment
    state = env.reset()

    #flag to see if maze was solved in current episode
    solvedMaze = False

    #loop for number of episodes
    while current_step_number < number_episodes:
        #define several arrays for different functions
        rewards = []

        #for the 5 step updates
        for _ in range(num_step_td_update):
            #get random action
            action = env.action_space.sample()

            #take step
            state_prime,reward,done,_ = env.step(action)

            #OWN REWARD DEFINITIONS
            #if agent reached end of maze
            if state_prime['blstats'][0] == 27 and state_prime['blstats'][1] == 11:
                #if it is not the same episode that has reached maze exit already
                if len(scores) not in np.array(solved_count):  
                    #print that it solved maze
                    print("Solved maze")
                    solvedMaze = True
                    #append which episode the maze was solved
                    solved_count.append(len(scores))
                    #increment times maze has been exited
                    countSubtaskDone[0] = countSubtaskDone[0] + 1
                    #give large positive reward
                reward += 100            

            #add correct quantities to correct lists   
            scores[-1]+=reward
            rewards.append(reward)
            
            #increment step number and update state
            current_step_number += 1
            state = state_prime           
                

            #if episode is done
            if done:
                #print episode stats
                print("episodes: {}".format(len(scores)),"ep reward: {}".format(scores[-1]))
                #reset env
                state = env.reset()
                #add zero to scores
                scores.append(0.0)

        #similar to above
        action = env.action_space.sample()

    #print episodes that finished maze
    print('episodes that solved maze', np.unique(np.array(solved_count)))
    return scores.copy(),countSubtaskDone

# %% [markdown]
# # Main Driver Code

# %% [markdown]
# We set up the environment and altered action space. Create AC model and agent. Train using function above for 100 episodes with gamma = 0 and the learning rate = 0.001.

# %%
def main(seed):
    #define MiniHack-Quest-Hard-v0 env for training with altered action space
    env = gym.make("MiniHack-Quest-Hard-v0",observation_keys=("colors_crop","blstats"), savedir="/content/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/videos/") 
    
    # seeds for reproductions
    env.seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    
    # hyper-parameters used during training
    gamma = 0
    learning_rate = 0.001
    number_episodes = 200000
        
    #train
    scores,countSubtask = train_ac(env, number_episodes, gamma, verbose=True)

    #close env after training
    env.close()

    #pass to cell below for plotting
    return scores,countSubtask

# %% [markdown]
# ## Running Main and Do Necessary Plots

# %% [markdown]
# Run Main above. Save necessary numpy arrays to make comparison plots between agents. Create plots needed for project and save plots.

# %%
if __name__ == '__main__': 
    #arrays to store rewards and subtask counts for each run
    allRunScores = []
    allRunCountSubtasks = []

    #do three runs of training
    for i in range(3):
      print()
      print("Training Run "+str(i))
      print("----------------------------------------------------------------")
      #pick random seed for run and pass to main
      seed = np.random.randint(100)
      scores,countSubtask = main(seed)
      #store rewards and subtask counts for run
      allRunScores.append(scores[:199])
      allRunCountSubtasks.append(countSubtask)
      #save arrays of each per run
      np.save(cwd+"/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/scoresRun"+str(i)+".npy", np.array(scores), allow_pickle=True)
      np.save(cwd+"/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/subtaskCountsRun"+str(i)+".npy", np.array(countSubtask), allow_pickle=True)

    #make line graph plots showing rewards per episode per run
    plt.figure(figsize=(8,8))
    plt.plot(allRunScores[0],label="Run 1")
    plt.plot(allRunScores[1],label="Run 2")
    plt.plot(allRunScores[2],label="Run 3")
    plt.ylabel("Reward")
    plt.xlabel("episode")
    plt.title("Reward per Episode for 3 runs during Training")
    plt.savefig(cwd+'/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/img/ACRandom-Training Rewards Per Runs.png')
    plt.show()

    #make line graphs showing average reward from runs
    allRunScoresMean = np.mean(np.array(allRunScores),axis = 0)
    np.save(cwd+"/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/scoresMean.npy", allRunScoresMean, allow_pickle=True)
    plt.figure(figsize=(8,8))
    plt.plot(allRunScoresMean)
    plt.ylabel("Mean Reward")
    plt.xlabel("Episode")
    plt.title("Mean Reward per Episode over all runs during Training")
    plt.savefig(cwd+'/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/img/ACRandom-Mean Training Rewards.png')
    plt.show()

    #make multiple bar plot showing subtask counts completed per run
    N = 4
    ind = np.arange(N) 
    width = 0.25
    allRunCountSubtasks = np.array(allRunCountSubtasks)
    xvals = allRunCountSubtasks[0]
    bar1 = plt.bar(ind, xvals, width, color = 'r') 
    yvals = allRunCountSubtasks[1]
    bar2 = plt.bar(ind+width, yvals, width, color='g')     
    zvals = allRunCountSubtasks[2]
    bar3 = plt.bar(ind+width*2, zvals, width, color = 'b')
    plt.ylabel("Subtask")
    plt.xlabel("Number of times subtasks completed during training per Run")
    plt.title("Bar graph showing number of times subtasks have been completed per Run during training")
    plt.xticks(ind+width,['Maze Exit Reached', 'Crossed Lava', 'Defeat Demon', 'Reach Staircase'])
    plt.legend( (bar1, bar2, bar3), ('Run 1', 'Run 2', 'Run 3') )
    plt.savefig(cwd+'/drive/My Drive/Colab Notebooks/Actor Critic Agents/Actor Critic - Random Agent/img/ACRandom-SubtasksPlotPerRun.png')
    plt.show()
# Out:
# Training Run 0
# ----------------------------------------------------------------
# episodes: 1 ep reward: -9.449999999999843
# episodes: 2 ep reward: -9.489999999999842
# episodes: 3 ep reward: -9.489999999999842
# episodes: 4 ep reward: -9.319999999999846
# episodes: 5 ep reward: -7.119999999999893
# episodes: 6 ep reward: -9.449999999999843
# episodes: 7 ep reward: -3.7299999999999645
# episodes: 8 ep reward: -9.469999999999843
# episodes: 9 ep reward: -8.64999999999986
# episodes: 10 ep reward: -9.449999999999843
# episodes: 11 ep reward: -9.389999999999844
# episodes: 12 ep reward: -9.409999999999844
# episodes: 13 ep reward: -9.319999999999846
# episodes: 14 ep reward: -9.509999999999842
# episodes: 15 ep reward: -9.469999999999843
# episodes: 16 ep reward: -9.469999999999843
# episodes: 17 ep reward: -9.379999999999844
# episodes: 18 ep reward: -9.469999999999843
# episodes: 19 ep reward: -9.399999999999844
# episodes: 20 ep reward: -9.399999999999844
# episodes: 21 ep reward: -9.529999999999841
# episodes: 22 ep reward: -9.459999999999843
# episodes: 23 ep reward: -8.65999999999986
# episodes: 24 ep reward: -9.439999999999843
# episodes: 25 ep reward: -3.3399999999999728
# episodes: 26 ep reward: -9.319999999999846
# episodes: 27 ep reward: -9.639999999999839
# episodes: 28 ep reward: -9.479999999999842
# episodes: 29 ep reward: -9.509999999999842
# episodes: 30 ep reward: -9.359999999999845
# episodes: 31 ep reward: -9.369999999999845
# episodes: 32 ep reward: -9.479999999999842
# /usr/local/lib/python3.7/dist-packages/nle/env/base.py:695: UserWarning: Warning: smooth quitting of game failed, aborting.
#   warnings.warn("Warning: smooth quitting of game failed, aborting.")
# episodes: 33 ep reward: -9.519999999999841
# episodes: 34 ep reward: -9.489999999999842
# episodes: 35 ep reward: -9.529999999999841
# episodes: 36 ep reward: -9.459999999999843
# episodes: 37 ep reward: -9.419999999999844
# episodes: 38 ep reward: -9.459999999999843
# episodes: 39 ep reward: -9.339999999999845
# episodes: 40 ep reward: -9.59999999999984
# episodes: 41 ep reward: -9.459999999999843
# episodes: 42 ep reward: -9.439999999999843
# episodes: 43 ep reward: -9.56999999999984
# episodes: 44 ep reward: -9.439999999999843
# episodes: 45 ep reward: -3.0299999999999794
# episodes: 46 ep reward: -9.419999999999844
# episodes: 47 ep reward: -6.379999999999908
# episodes: 48 ep reward: -9.409999999999844
# episodes: 49 ep reward: -9.499999999999842
# episodes: 50 ep reward: -9.56999999999984
# episodes: 51 ep reward: -9.339999999999845
# episodes: 52 ep reward: -9.289999999999846
# episodes: 53 ep reward: -9.529999999999841
# episodes: 54 ep reward: -4.0299999999999585
# episodes: 55 ep reward: -9.539999999999841
# episodes: 56 ep reward: -9.379999999999844
# episodes: 57 ep reward: -9.699999999999838
# episodes: 58 ep reward: -9.409999999999844
# episodes: 59 ep reward: -9.529999999999841
# episodes: 60 ep reward: -9.419999999999844
# episodes: 61 ep reward: -9.499999999999842
# episodes: 62 ep reward: -9.309999999999846
# episodes: 63 ep reward: -9.59999999999984
# episodes: 64 ep reward: -9.469999999999843
# episodes: 65 ep reward: -9.419999999999844
# episodes: 66 ep reward: -8.109999999999872
# episodes: 67 ep reward: -9.57999999999984
# episodes: 68 ep reward: -9.509999999999842
# episodes: 69 ep reward: -9.55999999999984
# episodes: 70 ep reward: -6.059999999999915
# episodes: 71 ep reward: -7.049999999999894
# episodes: 72 ep reward: -9.429999999999843
# episodes: 73 ep reward: -5.029999999999937
# episodes: 74 ep reward: -9.309999999999846
# episodes: 75 ep reward: -8.909999999999854
# episodes: 76 ep reward: -9.359999999999845
# episodes: 77 ep reward: -9.479999999999842
# episodes: 78 ep reward: -9.359999999999845
# episodes: 79 ep reward: -9.349999999999845
# episodes: 80 ep reward: -9.379999999999844
# episodes: 81 ep reward: -9.54999999999984
# episodes: 82 ep reward: -9.57999999999984
# episodes: 83 ep reward: -9.60999999999984
# episodes: 84 ep reward: -9.57999999999984
# episodes: 85 ep reward: -9.58999999999984
# episodes: 86 ep reward: -9.339999999999845
# episodes: 87 ep reward: -9.54999999999984
# episodes: 88 ep reward: -5.81999999999992
# episodes: 89 ep reward: -9.639999999999839
# episodes: 90 ep reward: -9.469999999999843
# episodes: 91 ep reward: -2.6499999999999875
# episodes: 92 ep reward: -9.199999999999848
# episodes: 93 ep reward: -9.509999999999842
# episodes: 94 ep reward: -9.419999999999844
# episodes: 95 ep reward: -9.319999999999846
# episodes: 96 ep reward: -9.479999999999842
# episodes: 97 ep reward: -9.439999999999843
# episodes: 98 ep reward: -9.399999999999844
# episodes: 99 ep reward: -9.409999999999844
# episodes: 100 ep reward: -9.429999999999843
# episodes: 101 ep reward: -9.14999999999985
# episodes: 102 ep reward: -9.499999999999842
# episodes: 103 ep reward: -9.319999999999846
# episodes: 104 ep reward: -9.419999999999844
# episodes: 105 ep reward: -9.489999999999842
# episodes: 106 ep reward: -9.389999999999844
# episodes: 107 ep reward: -9.479999999999842
# episodes: 108 ep reward: -5.879999999999919
# episodes: 109 ep reward: -9.489999999999842
# episodes: 110 ep reward: -9.439999999999843
# episodes: 111 ep reward: -9.319999999999846
# episodes: 112 ep reward: -9.389999999999844
# episodes: 113 ep reward: -9.479999999999842
# episodes: 114 ep reward: -9.519999999999841
# episodes: 115 ep reward: -9.409999999999844
# episodes: 116 ep reward: -9.489999999999842
# episodes: 117 ep reward: -4.3599999999999515
# episodes: 118 ep reward: -9.449999999999843
# episodes: 119 ep reward: -9.489999999999842
# episodes: 120 ep reward: -9.469999999999843
# episodes: 121 ep reward: -9.449999999999843
# episodes: 122 ep reward: -8.14999999999987
# episodes: 123 ep reward: -9.56999999999984
# episodes: 124 ep reward: -9.409999999999844
# episodes: 125 ep reward: -9.539999999999841
# episodes: 126 ep reward: -9.369999999999845
# episodes: 127 ep reward: -4.459999999999949
# episodes: 128 ep reward: -9.469999999999843
# episodes: 129 ep reward: -9.61999999999984
# episodes: 130 ep reward: -9.449999999999843
# episodes: 131 ep reward: -9.319999999999846
# episodes: 132 ep reward: -9.54999999999984
# episodes: 133 ep reward: -9.499999999999842
# episodes: 134 ep reward: -9.519999999999841
# episodes: 135 ep reward: -2.099999999999999
# episodes: 136 ep reward: -7.939999999999875
# episodes: 137 ep reward: -9.409999999999844
# episodes: 138 ep reward: -9.479999999999842
# episodes: 139 ep reward: -9.55999999999984
# episodes: 140 ep reward: -9.429999999999843
# episodes: 141 ep reward: -9.469999999999843
# episodes: 142 ep reward: -9.639999999999839
# episodes: 143 ep reward: -9.389999999999844
# episodes: 144 ep reward: -9.379999999999844
# episodes: 145 ep reward: -9.499999999999842
# episodes: 146 ep reward: -9.56999999999984
# episodes: 147 ep reward: -9.59999999999984
# episodes: 148 ep reward: -9.499999999999842
# episodes: 149 ep reward: -9.189999999999849
# episodes: 150 ep reward: -9.379999999999844
# episodes: 151 ep reward: -9.499999999999842
# episodes: 152 ep reward: -9.329999999999846
# episodes: 153 ep reward: -9.57999999999984
# episodes: 154 ep reward: -9.369999999999845
# episodes: 155 ep reward: -7.999999999999874
# episodes: 156 ep reward: -9.07999999999985
# episodes: 157 ep reward: -9.389999999999844
# episodes: 158 ep reward: -6.7799999999999
# episodes: 159 ep reward: -9.459999999999843
# episodes: 160 ep reward: -9.469999999999843
# episodes: 161 ep reward: -9.469999999999843
# episodes: 162 ep reward: -9.479999999999842
# episodes: 163 ep reward: -7.70999999999988
# episodes: 164 ep reward: -9.639999999999839
# episodes: 165 ep reward: -9.519999999999841
# episodes: 166 ep reward: -9.459999999999843
# episodes: 167 ep reward: -9.09999999999985
# episodes: 168 ep reward: -9.419999999999844
# episodes: 169 ep reward: -5.3899999999999295
# episodes: 170 ep reward: -9.329999999999846
# episodes: 171 ep reward: -9.419999999999844
# episodes: 172 ep reward: -9.339999999999845
# episodes: 173 ep reward: -9.369999999999845
# episodes: 174 ep reward: -9.349999999999845
# episodes: 175 ep reward: -9.429999999999843
# episodes: 176 ep reward: -9.499999999999842
# episodes: 177 ep reward: -9.389999999999844
# episodes: 178 ep reward: -9.389999999999844
# episodes: 179 ep reward: -2.3599999999999937
# episodes: 180 ep reward: -9.259999999999847
# episodes: 181 ep reward: -9.319999999999846
# episodes: 182 ep reward: -9.689999999999838
# episodes: 183 ep reward: -9.57999999999984
# episodes: 184 ep reward: -2.439999999999992
# episodes: 185 ep reward: -9.409999999999844
# episodes: 186 ep reward: -9.379999999999844
# episodes: 187 ep reward: -9.409999999999844
# Solved maze
# episodes: 188 ep reward: 15290.55999999987
# episodes: 189 ep reward: -9.429999999999843
# episodes: 190 ep reward: -9.469999999999843
# episodes: 191 ep reward: -9.359999999999845
# episodes: 192 ep reward: -9.409999999999844
# episodes: 193 ep reward: -5.35999999999993
# episodes: 194 ep reward: -9.419999999999844
# episodes: 195 ep reward: -9.489999999999842
# episodes: 196 ep reward: -9.399999999999844
# episodes: 197 ep reward: -9.479999999999842
# episodes: 198 ep reward: -9.359999999999845
# episodes: 199 ep reward: -9.419999999999844
# episodes: 200 ep reward: -9.62999999999984
# episodes: 201 ep reward: -9.369999999999845
# episodes: 202 ep reward: -9.519999999999841
# episodes: 203 ep reward: -2.439999999999992
# episodes: 204 ep reward: -9.519999999999841
# episodes: 205 ep reward: -2.3099999999999947
# episodes: 206 ep reward: -7.4999999999998845
# episodes: 207 ep reward: -9.479999999999842
# episodes: 208 ep reward: -9.439999999999843
# episodes: 209 ep reward: -9.419999999999844
# episodes: 210 ep reward: -9.539999999999841
# episodes: 211 ep reward: -9.519999999999841
# episodes: 212 ep reward: -9.439999999999843
# episodes that solved maze [188]
#
# Training Run 1
# ----------------------------------------------------------------
# episodes: 1 ep reward: -9.499999999999842
# episodes: 2 ep reward: -9.55999999999984
# episodes: 3 ep reward: -9.359999999999845
# episodes: 4 ep reward: -7.8299999999998775
# episodes: 5 ep reward: -6.269999999999911
# episodes: 6 ep reward: -9.419999999999844
# episodes: 7 ep reward: -4.489999999999949
# episodes: 8 ep reward: -9.479999999999842
# episodes: 9 ep reward: -9.469999999999843
# episodes: 10 ep reward: -9.439999999999843
# episodes: 11 ep reward: -9.59999999999984
# episodes: 12 ep reward: -9.489999999999842
# episodes: 13 ep reward: -9.539999999999841
# episodes: 14 ep reward: -9.60999999999984
# episodes: 15 ep reward: -9.419999999999844
# episodes: 16 ep reward: -9.409999999999844
# episodes: 17 ep reward: -9.539999999999841
# episodes: 18 ep reward: -9.399999999999844
# episodes: 19 ep reward: -9.469999999999843
# episodes: 20 ep reward: -9.55999999999984
# episodes: 21 ep reward: -9.419999999999844
# episodes: 22 ep reward: -7.169999999999892
# episodes: 23 ep reward: -9.479999999999842
# episodes: 24 ep reward: -9.349999999999845
# episodes: 25 ep reward: -9.469999999999843
# episodes: 26 ep reward: -9.509999999999842
# episodes: 27 ep reward: -9.259999999999847
# episodes: 28 ep reward: -9.419999999999844
# episodes: 29 ep reward: -9.369999999999845
# episodes: 30 ep reward: -9.62999999999984
# episodes: 31 ep reward: -9.319999999999846
# episodes: 32 ep reward: -9.55999999999984
# episodes: 33 ep reward: -4.40999999999995
# episodes: 34 ep reward: -9.60999999999984
# episodes: 35 ep reward: -9.57999999999984
# episodes: 36 ep reward: -9.479999999999842
# episodes: 37 ep reward: -9.389999999999844
# episodes: 38 ep reward: -9.319999999999846
# episodes: 39 ep reward: -9.369999999999845
# episodes: 40 ep reward: -9.55999999999984
# episodes: 41 ep reward: -9.55999999999984
# episodes: 42 ep reward: -5.069999999999936
# episodes: 43 ep reward: -9.379999999999844
# episodes: 44 ep reward: -9.359999999999845
# episodes: 45 ep reward: -9.55999999999984
# episodes: 46 ep reward: -9.529999999999841
# episodes: 47 ep reward: -9.369999999999845
# episodes: 48 ep reward: -9.409999999999844
# episodes: 49 ep reward: -9.449999999999843
# episodes: 50 ep reward: -9.419999999999844
# episodes: 51 ep reward: -9.60999999999984
# episodes: 52 ep reward: -9.239999999999847
# episodes: 53 ep reward: -1.380000000000001
# episodes: 54 ep reward: -8.129999999999871
# episodes: 55 ep reward: -9.469999999999843
# episodes: 56 ep reward: -9.449999999999843
# episodes: 57 ep reward: -9.539999999999841
# episodes: 58 ep reward: -9.419999999999844
# episodes: 59 ep reward: -9.499999999999842
# episodes: 60 ep reward: -9.379999999999844
# episodes: 61 ep reward: -7.149999999999892
# episodes: 62 ep reward: -9.449999999999843
# episodes: 63 ep reward: -9.369999999999845
# episodes: 64 ep reward: -9.399999999999844
# episodes: 65 ep reward: -9.349999999999845
# episodes: 66 ep reward: -9.479999999999842
# episodes: 67 ep reward: -9.389999999999844
# episodes: 68 ep reward: -9.429999999999843
# episodes: 69 ep reward: -9.419999999999844
# episodes: 70 ep reward: -9.539999999999841
# episodes: 71 ep reward: -9.439999999999843
# episodes: 72 ep reward: -9.489999999999842
# episodes: 73 ep reward: -9.449999999999843
# episodes: 74 ep reward: -9.309999999999846
# episodes: 75 ep reward: -9.56999999999984
# episodes: 76 ep reward: -9.679999999999838
# episodes: 77 ep reward: -9.519999999999841
# episodes: 78 ep reward: -3.789999999999963
# episodes: 79 ep reward: -9.359999999999845
# episodes: 80 ep reward: -9.439999999999843
# episodes: 81 ep reward: -9.529999999999841
# episodes: 82 ep reward: -9.519999999999841
# episodes: 83 ep reward: -7.049999999999894
# episodes: 84 ep reward: -9.519999999999841
# episodes: 85 ep reward: -9.389999999999844
# episodes: 86 ep reward: -9.59999999999984
# episodes: 87 ep reward: -9.509999999999842
# episodes: 88 ep reward: -9.479999999999842
# episodes: 89 ep reward: -5.37999999999993
# episodes: 90 ep reward: -9.479999999999842
# episodes: 91 ep reward: -8.949999999999854
# episodes: 92 ep reward: -9.539999999999841
# episodes: 93 ep reward: -9.349999999999845
# episodes: 94 ep reward: -9.419999999999844
# episodes: 95 ep reward: -9.359999999999845
# episodes: 96 ep reward: -9.54999999999984
# episodes: 97 ep reward: -5.139999999999935
# episodes: 98 ep reward: -9.459999999999843
# episodes: 99 ep reward: -9.459999999999843
# episodes: 100 ep reward: -6.579999999999904
# episodes: 101 ep reward: -9.54999999999984
# episodes: 102 ep reward: -9.479999999999842
# episodes: 103 ep reward: -9.359999999999845
# episodes: 104 ep reward: -9.419999999999844
# episodes: 105 ep reward: -6.219999999999912
# episodes: 106 ep reward: -9.479999999999842
# episodes: 107 ep reward: -9.429999999999843
# episodes: 108 ep reward: -9.55999999999984
# episodes: 109 ep reward: -9.719999999999837
# episodes: 110 ep reward: -9.439999999999843
# episodes: 111 ep reward: -9.409999999999844
# episodes: 112 ep reward: -9.489999999999842
# episodes: 113 ep reward: -9.249999999999847
# episodes: 114 ep reward: -9.519999999999841
# episodes: 115 ep reward: -9.439999999999843
# episodes: 116 ep reward: -9.469999999999843
# episodes: 117 ep reward: -9.409999999999844
# episodes: 118 ep reward: -4.279999999999953
# episodes: 119 ep reward: -9.479999999999842
# episodes: 120 ep reward: -6.029999999999916
# episodes: 121 ep reward: -9.439999999999843
# episodes: 122 ep reward: -9.409999999999844
# episodes: 123 ep reward: -9.499999999999842
# episodes: 124 ep reward: -9.419999999999844
# episodes: 125 ep reward: -9.499999999999842
# episodes: 126 ep reward: -9.08999999999985
# episodes: 127 ep reward: -9.329999999999846
# episodes: 128 ep reward: -9.389999999999844
# episodes: 129 ep reward: -9.499999999999842
# episodes: 130 ep reward: -9.239999999999847
# episodes: 131 ep reward: -9.56999999999984
# episodes: 132 ep reward: -9.319999999999846
# episodes: 133 ep reward: -9.479999999999842
# episodes: 134 ep reward: -9.529999999999841
# episodes: 135 ep reward: -9.429999999999843
# episodes: 136 ep reward: -6.9399999999998965
# episodes: 137 ep reward: -9.389999999999844
# episodes: 138 ep reward: -4.849999999999941
# episodes: 139 ep reward: -9.429999999999843
# episodes: 140 ep reward: -9.429999999999843
# episodes: 141 ep reward: -9.419999999999844
# episodes: 142 ep reward: -0.8200000000000005
# episodes: 143 ep reward: -9.439999999999843
# episodes: 144 ep reward: -9.499999999999842
# episodes: 145 ep reward: -5.969999999999917
# episodes: 146 ep reward: -9.59999999999984
# episodes: 147 ep reward: -9.319999999999846
# episodes: 148 ep reward: -9.419999999999844
# episodes: 149 ep reward: -9.429999999999843
# episodes: 150 ep reward: -9.439999999999843
# episodes: 151 ep reward: -9.449999999999843
# episodes: 152 ep reward: -2.249999999999996
# episodes: 153 ep reward: -9.439999999999843
# episodes: 154 ep reward: -9.479999999999842
# episodes: 155 ep reward: -9.369999999999845
# episodes: 156 ep reward: -6.949999999999896
# episodes: 157 ep reward: -9.349999999999845
# episodes: 158 ep reward: -9.199999999999848
# episodes: 159 ep reward: -9.62999999999984
# episodes: 160 ep reward: -9.639999999999839
# episodes: 161 ep reward: -9.409999999999844
# episodes: 162 ep reward: -9.419999999999844
# episodes: 163 ep reward: -9.479999999999842
# episodes: 164 ep reward: -9.269999999999847
# episodes: 165 ep reward: -7.869999999999877
# episodes: 166 ep reward: -9.419999999999844
# episodes: 167 ep reward: -6.399999999999908
# episodes: 168 ep reward: -9.419999999999844
# episodes: 169 ep reward: -9.509999999999842
# episodes: 170 ep reward: -9.189999999999849
# episodes: 171 ep reward: -9.54999999999984
# episodes: 172 ep reward: -9.539999999999841
# episodes: 173 ep reward: -7.5499999999998835
# episodes: 174 ep reward: -9.449999999999843
# episodes: 175 ep reward: -9.209999999999848
# episodes: 176 ep reward: -9.429999999999843
# episodes: 177 ep reward: -4.079999999999957
# episodes: 178 ep reward: -9.389999999999844
# episodes: 179 ep reward: -9.359999999999845
# episodes: 180 ep reward: -9.469999999999843
# episodes: 181 ep reward: -9.449999999999843
# episodes: 182 ep reward: -9.419999999999844
# episodes: 183 ep reward: -9.399999999999844
# episodes: 184 ep reward: -9.679999999999838
# episodes: 185 ep reward: -9.489999999999842
# episodes: 186 ep reward: -9.329999999999846
# episodes: 187 ep reward: -9.459999999999843
# episodes: 188 ep reward: -9.329999999999846
# episodes: 189 ep reward: -9.299999999999846
# episodes: 190 ep reward: -8.769999999999857
# episodes: 191 ep reward: -9.749999999999837
# episodes: 192 ep reward: -9.439999999999843
# episodes: 193 ep reward: -9.469999999999843
# episodes: 194 ep reward: -9.479999999999842
# episodes: 195 ep reward: -9.369999999999845
# episodes: 196 ep reward: -9.489999999999842
# episodes: 197 ep reward: -3.759999999999964
# episodes: 198 ep reward: -9.409999999999844
# episodes: 199 ep reward: -9.509999999999842
# episodes: 200 ep reward: -9.55999999999984
# episodes: 201 ep reward: -9.529999999999841
# episodes: 202 ep reward: -9.359999999999845
# episodes: 203 ep reward: -6.059999999999915
# episodes: 204 ep reward: -9.399999999999844
# episodes: 205 ep reward: -9.419999999999844
# episodes: 206 ep reward: -9.59999999999984
# episodes: 207 ep reward: -9.539999999999841
# episodes: 208 ep reward: -9.369999999999845
# episodes: 209 ep reward: -8.18999999999987
# episodes: 210 ep reward: -9.379999999999844
# episodes: 211 ep reward: -9.55999999999984
# episodes: 212 ep reward: -9.409999999999844
# episodes that solved maze []
#
# Training Run 2
# ----------------------------------------------------------------
# episodes: 1 ep reward: -9.239999999999847
# episodes: 2 ep reward: -9.55999999999984
# episodes: 3 ep reward: -3.9699999999999593
# episodes: 4 ep reward: -9.439999999999843
# episodes: 5 ep reward: -7.809999999999878
# episodes: 6 ep reward: -9.369999999999845
# episodes: 7 ep reward: -9.389999999999844
# episodes: 8 ep reward: -9.439999999999843
# episodes: 9 ep reward: -9.56999999999984
# episodes: 10 ep reward: -9.429999999999843
# episodes: 11 ep reward: -9.469999999999843
# episodes: 12 ep reward: -9.389999999999844
# episodes: 13 ep reward: -9.449999999999843
# episodes: 14 ep reward: -8.309999999999867
# episodes: 15 ep reward: -9.449999999999843
# episodes: 16 ep reward: -2.1199999999999988
# episodes: 17 ep reward: -9.489999999999842
# episodes: 18 ep reward: -8.949999999999854
# episodes: 19 ep reward: -9.519999999999841
# episodes: 20 ep reward: -9.439999999999843
# episodes: 21 ep reward: -8.909999999999854
# episodes: 22 ep reward: -3.889999999999961
# episodes: 23 ep reward: -9.409999999999844
# episodes: 24 ep reward: -9.539999999999841
# episodes: 25 ep reward: -9.379999999999844
# episodes: 26 ep reward: -9.219999999999848
# episodes: 27 ep reward: -9.319999999999846
# episodes: 28 ep reward: -9.369999999999845
# episodes: 29 ep reward: -9.429999999999843
# episodes: 30 ep reward: -9.349999999999845
# episodes: 31 ep reward: -9.459999999999843
# episodes: 32 ep reward: -9.359999999999845
# episodes: 33 ep reward: -9.279999999999847
# episodes: 34 ep reward: -9.439999999999843
# episodes: 35 ep reward: -9.439999999999843
# episodes: 36 ep reward: -4.8299999999999415
# episodes: 37 ep reward: -9.62999999999984
# episodes: 38 ep reward: -3.3499999999999726
# episodes: 39 ep reward: -9.349999999999845
# episodes: 40 ep reward: -9.469999999999843
# episodes: 41 ep reward: -9.439999999999843
# episodes: 42 ep reward: -9.389999999999844
# episodes: 43 ep reward: -9.329999999999846
# episodes: 44 ep reward: -9.489999999999842
# episodes: 45 ep reward: -5.559999999999926
# episodes: 46 ep reward: -7.9699999999998745
# episodes: 47 ep reward: -5.619999999999925
# episodes: 48 ep reward: -9.409999999999844
# episodes: 49 ep reward: -7.5499999999998835
# episodes: 50 ep reward: -6.7699999999999
# episodes: 51 ep reward: -9.219999999999848
# episodes: 52 ep reward: -9.489999999999842
# episodes: 53 ep reward: -9.449999999999843
# episodes: 54 ep reward: -1.0900000000000007
# episodes: 55 ep reward: -9.55999999999984
# episodes: 56 ep reward: -9.399999999999844
# episodes: 57 ep reward: -9.649999999999839
# episodes: 58 ep reward: -9.12999999999985
# episodes: 59 ep reward: -9.399999999999844
# episodes: 60 ep reward: -7.979999999999874
# episodes: 61 ep reward: -8.089999999999872
# episodes: 62 ep reward: -9.379999999999844
# episodes: 63 ep reward: -9.409999999999844
# episodes: 64 ep reward: -9.439999999999843
# episodes: 65 ep reward: -9.499999999999842
# episodes: 66 ep reward: -9.419999999999844
# episodes: 67 ep reward: -7.529999999999884
# episodes: 68 ep reward: -9.339999999999845
# episodes: 69 ep reward: -9.309999999999846
# episodes: 70 ep reward: -9.489999999999842
# episodes: 71 ep reward: -9.299999999999846
# episodes: 72 ep reward: -9.279999999999847
# episodes: 73 ep reward: -9.469999999999843
# episodes: 74 ep reward: -9.419999999999844
# episodes: 75 ep reward: -9.459999999999843
# episodes: 76 ep reward: -9.499999999999842
# episodes: 77 ep reward: -9.419999999999844
# episodes: 78 ep reward: -9.419999999999844
# episodes: 79 ep reward: -9.509999999999842
# episodes: 80 ep reward: -9.239999999999847
# episodes: 81 ep reward: -9.519999999999841
# episodes: 82 ep reward: -1.9900000000000015
# episodes: 83 ep reward: -9.359999999999845
# episodes: 84 ep reward: -9.289999999999846
# episodes: 85 ep reward: -9.389999999999844
# episodes: 86 ep reward: -9.239999999999847
# episodes: 87 ep reward: -9.379999999999844
# episodes: 88 ep reward: -9.389999999999844
# episodes: 89 ep reward: -9.379999999999844
# episodes: 90 ep reward: -9.539999999999841
# episodes: 91 ep reward: -9.529999999999841
# episodes: 92 ep reward: -9.239999999999847
# episodes: 93 ep reward: -9.61999999999984
# episodes: 94 ep reward: -9.339999999999845
# episodes: 95 ep reward: -9.469999999999843
# episodes: 96 ep reward: -4.7799999999999425
# Solved maze
# episodes: 97 ep reward: 40490.42999999944
# episodes: 98 ep reward: -9.359999999999845
# episodes: 99 ep reward: -9.489999999999842
# episodes: 100 ep reward: -9.57999999999984
# episodes: 101 ep reward: -9.479999999999842
# episodes: 102 ep reward: -9.57999999999984
# episodes: 103 ep reward: -9.409999999999844
# episodes: 104 ep reward: -9.339999999999845
# episodes: 105 ep reward: -9.339999999999845
# episodes: 106 ep reward: -9.509999999999842
# episodes: 107 ep reward: -9.659999999999838
# episodes: 108 ep reward: -9.309999999999846
# episodes: 109 ep reward: -9.429999999999843
# episodes: 110 ep reward: -9.459999999999843
# episodes: 111 ep reward: -9.389999999999844
# episodes: 112 ep reward: -9.55999999999984
# episodes: 113 ep reward: -9.339999999999845
# episodes: 114 ep reward: -9.419999999999844
# episodes: 115 ep reward: -7.70999999999988
# episodes: 116 ep reward: -9.189999999999849
# episodes: 117 ep reward: -9.459999999999843
# episodes: 118 ep reward: -9.379999999999844
# episodes: 119 ep reward: -9.499999999999842
# episodes: 120 ep reward: -9.429999999999843
# episodes: 121 ep reward: -9.429999999999843
# episodes: 122 ep reward: -9.54999999999984
# episodes: 123 ep reward: -9.459999999999843
# episodes: 124 ep reward: -9.239999999999847
# episodes: 125 ep reward: -9.499999999999842
# episodes: 126 ep reward: -9.499999999999842
# episodes: 127 ep reward: -9.519999999999841
# episodes: 128 ep reward: -9.55999999999984
# episodes: 129 ep reward: -9.539999999999841
# episodes: 130 ep reward: -9.389999999999844
# episodes: 131 ep reward: -9.429999999999843
# episodes: 132 ep reward: -9.259999999999847
# episodes: 133 ep reward: -9.449999999999843
# episodes: 134 ep reward: -9.209999999999848
# episodes: 135 ep reward: -9.449999999999843
# episodes: 136 ep reward: -8.409999999999865
# episodes: 137 ep reward: -9.429999999999843
# episodes: 138 ep reward: -9.469999999999843
# episodes: 139 ep reward: -9.499999999999842
# episodes: 140 ep reward: -9.359999999999845
# episodes: 141 ep reward: -9.409999999999844
# episodes: 142 ep reward: -9.269999999999847
# episodes: 143 ep reward: -9.57999999999984
# episodes: 144 ep reward: -9.59999999999984
# episodes: 145 ep reward: -9.439999999999843
# episodes: 146 ep reward: -9.449999999999843
# episodes: 147 ep reward: -9.299999999999846
# episodes: 148 ep reward: -9.499999999999842
# episodes: 149 ep reward: -9.259999999999847
# episodes: 150 ep reward: -9.499999999999842
# episodes: 151 ep reward: -5.789999999999921
# episodes: 152 ep reward: -9.409999999999844
# episodes: 153 ep reward: -6.489999999999906
# episodes: 154 ep reward: -9.229999999999848
# episodes: 155 ep reward: -9.389999999999844
# episodes: 156 ep reward: -9.54999999999984
# episodes: 157 ep reward: -9.389999999999844
# episodes: 158 ep reward: -9.319999999999846
# episodes: 159 ep reward: -9.489999999999842
# episodes: 160 ep reward: -9.429999999999843
# episodes: 161 ep reward: -9.56999999999984
# episodes: 162 ep reward: -9.279999999999847
# episodes: 163 ep reward: -9.489999999999842
# episodes: 164 ep reward: -9.56999999999984
# episodes: 165 ep reward: -9.489999999999842
# episodes: 166 ep reward: -7.849999999999877
# episodes: 167 ep reward: -9.659999999999838
# episodes: 168 ep reward: -9.299999999999846
# episodes: 169 ep reward: -9.359999999999845
# episodes: 170 ep reward: -9.539999999999841
# episodes: 171 ep reward: -9.439999999999843
# episodes: 172 ep reward: -9.329999999999846
# episodes: 173 ep reward: -2.769999999999985
# episodes: 174 ep reward: -9.55999999999984
# episodes: 175 ep reward: -9.519999999999841
# episodes: 176 ep reward: -9.459999999999843
# episodes: 177 ep reward: -9.279999999999847
# episodes: 178 ep reward: -9.459999999999843
# episodes: 179 ep reward: -9.459999999999843
# episodes: 180 ep reward: -9.409999999999844
# episodes: 181 ep reward: -9.499999999999842
# episodes: 182 ep reward: -9.409999999999844
# episodes: 183 ep reward: -3.1699999999999764
# episodes: 184 ep reward: -9.519999999999841
# episodes: 185 ep reward: -9.399999999999844
# episodes: 186 ep reward: -0.6000000000000003
# episodes: 187 ep reward: -9.419999999999844
# episodes: 188 ep reward: -4.049999999999958
# episodes: 189 ep reward: -8.779999999999857
# episodes: 190 ep reward: -9.439999999999843
# episodes: 191 ep reward: -9.499999999999842
# episodes: 192 ep reward: -9.379999999999844
# episodes: 193 ep reward: -9.62999999999984
# episodes: 194 ep reward: -9.379999999999844
# episodes: 195 ep reward: -6.30999999999991
# episodes: 196 ep reward: -9.529999999999841
# episodes: 197 ep reward: -9.509999999999842
# episodes: 198 ep reward: -9.309999999999846
# episodes: 199 ep reward: -9.419999999999844
# episodes: 200 ep reward: -9.519999999999841
# episodes: 201 ep reward: -9.379999999999844
# episodes: 202 ep reward: -9.509999999999842
# episodes: 203 ep reward: -9.359999999999845
# episodes: 204 ep reward: -9.54999999999984
# episodes: 205 ep reward: -4.739999999999943
# episodes: 206 ep reward: -9.369999999999845
# episodes: 207 ep reward: -9.379999999999844
# episodes: 208 ep reward: -9.429999999999843
# episodes: 209 ep reward: -9.489999999999842
# episodes: 210 ep reward: -9.429999999999843
# episodes: 211 ep reward: -9.479999999999842
# episodes: 212 ep reward: -9.519999999999841
# episodes: 213 ep reward: -3.319999999999973
# episodes that solved maze [97]
